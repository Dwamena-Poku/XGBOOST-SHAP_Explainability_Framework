# %% [markdown]
# # Updated XGBoost–SHAP Canonical Analysis
# Regenerates benchmark, Ghanaian institutional, SHAP and lecturer outputs.

# %%
# %run ../code/fast_canonical_rebuild.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\Documents\THESIS 2026\Albert_XGBoost_SHAP (2)\Albert_XGBoost_SHAP\code\fast_canonical_rebuild.py:14
#      12 from sklearn.base import clone
#      13 from imblearn.over_sampling import SMOTE
# ---> 14 from xgboost import XGBClassifier
#      15 import shap, nbformat as nbf
#      16 ROOT=Path('/mnt/data/Albert_XGBoost_SHAP_Updated_Package'); SEED=42
#
# ModuleNotFoundError: No module named 'xgboost'
